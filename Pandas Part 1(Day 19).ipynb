# %%
# !pip install pandas

# %%
import pandas as pd

# %%
# How to perform reading operation in Pandas.
mydata = pd.read_csv(r"C:\Users\USER\Downloads\SalesforcePractise.csv") # Here to read file, we shall also add r at the start otherwise it won't work.
# If column is not given in the data, first row will be considered as heading.
# Data which is starting from 0 in the below data is called row index. It will create it by default.
mydata
# Out:
#    First Name Last Name    Phone           Email   Marks
# 0    Rishiraj     Singh  652452.0   test@test.com      5
# 1         Raj   Rajawat  554521.0  test1@test.com     10
# 2       Pawan     Singh   22455.0  test2@test.com      8
# 3       Mehul    Choksi       NaN  test3@test.com      7
# 4       Vijay    Maliya   52583.0  test4@test.com      9
# 5       Vijay    Maliya   52608.0  test4@test.com     67
# 6       Vijay    Maliya   52633.0  test4@test.com    125
# 7       Vijay    Maliya   52658.0  test4@test.com    183
# 8       Vijay    Maliya   52683.0  test4@test.com    241
# 9       Vijay    Maliya   52708.0  test4@test.com    299
# 10      Vijay    Maliya   52733.0  test4@test.com    357
# 11      Vijay    Maliya   52758.0  test4@test.com    415
# 12      Vijay    Maliya   52783.0  test4@test.com    473
# 13      Vijay    Maliya   52808.0  test4@test.com    531
# 14      Vijay    Maliya   52833.0  test4@test.com    589
# ...

# %%
# Pandas will always return data in structured format.

# %%
#To see first and last records of the data.

df1 = mydata.head(10)
mydata.tail()
# Out:
#    First Name Last Name   Phone           Email   Marks
# 32      Vijay    Maliya  53283.0  test4@test.com   1633
# 33      Vijay    Maliya  53308.0  test4@test.com   1691
# 34      Vijay    Maliya  53333.0  test4@test.com   1749
# 35      Vijay    Maliya  53358.0  test4@test.com   1807
# 36      Vijay    Maliya  53383.0  test4@test.com   1865

# %%
type(mydata)
# Out:
# pandas.core.frame.DataFrame

# %%
# To store data
df1.to_csv("test.csv")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[7], line 2
#       1 # To store data
# ----> 2 df1.to_csv("test.csv")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:3902, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3891 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3893 formatter = DataFrameFormatter(
#    3894     frame=df,
#    3895     header=header,
#    (...)
#    3899     decimal=decimal,
#    3900 )
# -> 3902 return DataFrameRenderer(formatter).to_csv(
#    3903     path_or_buf,
#    3904     lineterminator=lineterminator,
#    3905     sep=sep,
#    3906     encoding=encoding,
#    3907     errors=errors,
# ...

# %%
pwd()

# %%
pd.read_csv("C:\\Users\\USER\\Desktop\\Full Stack Data Science (Ineuron)\\test.csv")

# %%
# In the above data, it has added one more addition column.

# %%
# If we want to ignore first column or any column from the data.

df = pd.read_csv("C:\\Users\\USER\\Desktop\\Full Stack Data Science (Ineuron)\\test.csv",sep=',',header=None, names=['a','b','c','d','e','f'],skiprows=[0,1],na_values=' ')

# If we have data with other seprator, we can put it under sep.
# We can make changes in the header as well. by default it gives first line as a header.
# with names we can give name to the column
# we can skiprows by giving the index.
# na_values =

# %%
df.describe()
# describe function gives details of number data by default.
# count = Number of record/rows in the data.
# mean = average
# Standard deviation
#  minimum
# maximum
# 25% 
# Example = 1,1,2,2,3,3,4,4,5,6,7 (column)
# Count = 10
# min = 1
# max = 7
# 25% = It's a 25th percentile data, means in the above case, 25% of 10th column after arranging it in the ascending order.

# %%
df.dtypes
# Pandas always try to under datatype by itself.

# %%
df = pd.read_csv("C:\\Users\\USER\\Desktop\\Full Stack Data Science (Ineuron)\\test.csv",sep=',')

# %%
mydata.to_csv("myfiltereddata3.csv",index=False, header=True, columns=["First Name"])
# index = False will remove the first column entirely which consist of 0,1,2,3,4 when we do pandas operations.
# header = False will remove the first row/header from the data.
# With column we can show only that column which we want. If we want to save selected column from the data.

# %%
mydata.columns # list of all columns
# Out:
# Index(['First Name', 'Last Name', 'Phone ', 'Email ', 'Marks'], dtype='object')

# %%
mydata['First Name'] # To access selected column. It's of series datatype.
# Out:
# 0     Rishiraj
# 1          Raj
# 2        Pawan
# 3        Mehul
# 4        Vijay
# 5        Vijay
# 6        Vijay
# 7        Vijay
# 8        Vijay
# 9        Vijay
# 10       Vijay
# 11       Vijay
# 12       Vijay
# 13       Vijay
# 14       Vijay
# 15       Vijay
# 16       Vijay
# 17       Vijay
# 18       Vijay
# 19       Vijay
# 20       Vijay
# 21       Vijay
# 22       Vijay
# 23       Vijay
# 24       Vijay
# 25       Vijay
# 26       Vijay
# 27       Vijay
# 28       Vijay
# 29       Vijay
# 30       Vijay
# 31       Vijay
# 32       Vijay
# 33       Vijay
# 34       Vijay
# 35       Vijay
# 36       Vijay
# Name: First Name, dtype: object

# %%
#There are two data types in pandas.

# Series : If you are extracting the single record and it's visible as series.Series is equilient to list. It's a subset of the dataframe.
# DataFrame

# %%
mydata[['First Name']] #This is of a dataframe datatype. We need to put it under a list.
# Out:
#    First Name
# 0    Rishiraj
# 1         Raj
# 2       Pawan
# 3       Mehul
# 4       Vijay
# 5       Vijay
# 6       Vijay
# 7       Vijay
# 8       Vijay
# 9       Vijay
# 10      Vijay
# 11      Vijay
# 12      Vijay
# 13      Vijay
# 14      Vijay
# 15      Vijay
# 16      Vijay
# 17      Vijay
# 18      Vijay
# 19      Vijay
# 20      Vijay
# 21      Vijay
# 22      Vijay
# 23      Vijay
# 24      Vijay
# 25      Vijay
# 26      Vijay
# 27      Vijay
# 28      Vijay
# 29      Vijay
# 30      Vijay
# 31      Vijay
# 32      Vijay
# 33      Vijay
# 34      Vijay
# 35      Vijay
# 36      Vijay

# %%
mydata['First Name','Last Name'] # This will not work, we need to put it into a list to make it working.
# Out:
#   Cell In[31], line 1
#     mydata['First Name','Last Name]
#                         ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
mydata[['First Name','Last Name']]
# Out:
# pandas.core.frame.DataFrame

# %%
pwd
# Out:
# 'C:\\Users\\USER\\Desktop\\Full Stack Data Science (Ineuron)'

# %%
cd C:\\Users\\USER\\Downloads
# Out:
# C:\Users\USER\Downloads

# %%
pwd
# Out:
# 'C:\\Users\\USER\\Downloads'

# %%
dff2 = pd.read_excel(r'C:\Users\USER\Desktop\Inventory-Records-Sample-Data.xlsx')
# If there are multiple tabs in the sheet, we can use sheet_name = sheet name to fetch the data.

# %%
# Excel RD is library to work on excel data.

# %%
# To read html 

dd= pd.read_html("https://www.basketball-reference.com/players/i/ibakase01.html?utm_source=direct&utm_medium=Share&utm_campaign=ShareTool")

# %%
type(dd)
# Out:
# list

# %%
len(dd) # Number of tables
# Out:
# 7

# %%
dd[0] # It has total 7 tables in it, to access 0th index table.
# Out:
#        Season   Age                                     Tm  \
# 0     2008-09  19.0  Did Not Play (other pro league—Spain)
# 1     2009-10  20.0                                    OKC
# 2     2010-11  21.0                                    OKC
# 3     2011-12  22.0                                    OKC
# 4     2012-13  23.0                                    OKC
# 5     2013-14  24.0                                    OKC
# 6     2014-15  25.0                                    OKC
# 7     2015-16  26.0                                    OKC
# 8     2016-17  27.0                                    TOT
# 9     2016-17  27.0                                    ORL
# 10    2016-17  27.0                                    TOR
# 11    2017-18  28.0                                    TOR
# 12    2018-19  29.0                                    TOR
# 13    2019-20  30.0                                    TOR
# 14    2020-21  31.0                                    LAC
# ...

# %%
# To access data from Github repository.
pd.read_csv("https://github.com/guipsamora/pandas_exercises/blob/master/06_Stats/US_Baby_Names/Solutions.csv")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[69], line 2
#       1 # To access data from Github repository.
# ----> 2 pd.read_csv("https://github.com/guipsamora/pandas_exercises/blob/master/06_Stats/US_Baby_Names/Solutions.csv")
#
# ...

# %%
# We are creating a data. tripple double column means multiline string, or docstring we can do or multi line chupane k liye just like #


rr = """ {
"name":"Rishi",
"phone": "8554587",
"Company":["Afyon","Zentek","Marktine"],
"Status": "True"}
"""

# %%
# To validata whether the data is JSON. Hit json viewer on Google.
import json

# %%
raj = json.loads(rr) # To convert data into Json.

# %%
raj
# Out:
# {'name': 'Rishi',
#  'phone': '8554587',
#  'Company': ['Afyon', 'Zentek', 'Marktine'],
#  'Status': 'True'}

# %%
# We would like to convert this data into dataframe to show in tabular form.
pd.DataFrame(raj)
# Out:
#     name    phone   Company Status
# 0  Rishi  8554587     Afyon   True
# 1  Rishi  8554587    Zentek   True
# 2  Rishi  8554587  Marktine   True

# %%
pd.DataFrame(raj, columns = ['Company'])
# Out:
#     Company
# 0     Afyon
# 1    Zentek
# 2  Marktine

# %%
import requests

# To get data from json url.

# %%
mydata = requests.get('https://api.github.com/repos/pandas-dev/pandas/issues')

# %%
mydata
# Out:
# <Response [200]>

# %%
new = mydata.json()
new
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58647',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58647/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58647/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58647/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/58647',
#   'id': 2286503427,
#   'node_id': 'PR_kwDOAA0YD85u7cjw',
#   'number': 58647,
#   'title': 'BLD, CI: Upload Emscripten/Pyodide nightlies to Anaconda index (`scientific-python-nightly-wheels`)',
#   'user': {'login': 'agriyakhetarpal',
#    'id': 74401230,
#    'node_id': 'MDQ6VXNlcjc0NDAxMjMw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/74401230?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/agriyakhetarpal',
# ...

# %%
# Parsing the data

filtered_data = pd.DataFrame(new) # converting into tabular format.
filtered_data
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
# 
filtered_data.url # Url from the data.
filtered_data.title # Titles from the data.

pd.DataFrame(new,columns=['title','url'])
# Out:
#                                                 title  \
# 0   BLD, CI: Upload Emscripten/Pyodide nightlies t...
# 1        CLN: int slice on Index[float] as positional
# 2   CLN: Stopped casting values in Series/Index.is...
# 3   BUG: inconsistent behavior of pandas.api.types...
# 4   BUG: RangeIndex.searchsorted() when using a ne...
# 5   BUG: Unable to open Stata 118 or 119 format fi...
# 6                           Enh/transform py fallback
# 7   BUG: Unable to open Stata 118 or 119 files sav...
# 8   BUG: `read_parquet` doesn't convert categories...
# 9   BUILD:  3rd party licenses are missing from pa...
# 10  BUG: pd.DataFrame.set_index() detects "label" ...
# 11                       Cln/separate logic from init
# 12                 PDEP-10: Change status to rejected
# 13  CLN: Enforce read_csv(keep_date_col, parse_dat...
# 14  BUG: Renaming a dataframe columns with a serie...
# 15  Default string dtype (PDEP-14): naming convent...
# ...

# %%
new[0]['title'] # The data is a list, we can also get details with the help for list comprehension.
# Out:
# 'BLD, CI: Upload Emscripten/Pyodide nightlies to Anaconda index (`scientific-python-nightly-wheels`)'

# %%
for i in range(len(new)):
    print(new[i]['title'])
# Out:
# BLD, CI: Upload Emscripten/Pyodide nightlies to Anaconda index (`scientific-python-nightly-wheels`)
# CLN: int slice on Index[float] as positional
# CLN: Stopped casting values in Series/Index.isin for datelike dtypes
# BUG: inconsistent behavior of pandas.api.types.pandas_dtype
# BUG: RangeIndex.searchsorted() when using a negative step
# BUG: Unable to open Stata 118 or 119 format files saved in big-endian…
# Enh/transform py fallback
# BUG: Unable to open Stata 118 or 119 files saved in big-endian format that contain strL data
# BUG: `read_parquet` doesn't convert categories to `pd.CategoricalDtype` when `dtype_backend="pyarrow"`
# BUILD:  3rd party licenses are missing from pandas binary wheels distributed on pypi
# BUG: pd.DataFrame.set_index() detects "label" input instead of "iterator" when keys argument is a list
# Cln/separate logic from init
# PDEP-10: Change status to rejected
# CLN: Enforce read_csv(keep_date_col, parse_dates) deprecations
# ...

# %%
for i in range(len(new)):
    print(new[i]['url'])
# Out:
# https://api.github.com/repos/pandas-dev/pandas/issues/58647
# https://api.github.com/repos/pandas-dev/pandas/issues/58646
# https://api.github.com/repos/pandas-dev/pandas/issues/58645
# https://api.github.com/repos/pandas-dev/pandas/issues/58643
# https://api.github.com/repos/pandas-dev/pandas/issues/58641
# https://api.github.com/repos/pandas-dev/pandas/issues/58640
# https://api.github.com/repos/pandas-dev/pandas/issues/58639
# https://api.github.com/repos/pandas-dev/pandas/issues/58638
# https://api.github.com/repos/pandas-dev/pandas/issues/58636
# https://api.github.com/repos/pandas-dev/pandas/issues/58632
# https://api.github.com/repos/pandas-dev/pandas/issues/58631
# https://api.github.com/repos/pandas-dev/pandas/issues/58628
# https://api.github.com/repos/pandas-dev/pandas/issues/58623
# https://api.github.com/repos/pandas-dev/pandas/issues/58622
# https://api.github.com/repos/pandas-dev/pandas/issues/58621
# https://api.github.com/repos/pandas-dev/pandas/issues/58613
# ...

# %%
# Task 

# Give User data in Dataframe format. [User is a nester dict]

# %%
newd= pd.DataFrame(new)

# %%
newd.user
liss = []
for i in newd.user:
    liss.append(i)
pd.DataFrame(liss)
# Out:
#                  login         id               node_id  \
# 0      agriyakhetarpal   74401230  MDQ6VXNlcjc0NDAxMjMw
# 1            mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 2            mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 3          aaravind100   98406957          U_kgDOBd2SLQ
# 4        michaelpradel    3207550  MDQ6VXNlcjMyMDc1NTA=
# 5          cmjcharlton   90400333  MDQ6VXNlcjkwNDAwMzMz
# 6     undermyumbrella1  120079323          U_kgDOByhD2w
# 7          cmjcharlton   90400333  MDQ6VXNlcjkwNDAwMzMz
# 8            nachomaiz   24781490  MDQ6VXNlcjI0NzgxNDkw
# 9            markdryan     984073  MDQ6VXNlcjk4NDA3Mw==
# 10     lucasmouragomes   14152572  MDQ6VXNlcjE0MTUyNTcy
# 11        PedroVerardo   99936353          U_kgDOBfToYQ
# 12           lithomas1   47963215  MDQ6VXNlcjQ3OTYzMjE1
# 13           mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 14           mixmixmix    9990867  MDQ6VXNlcjk5OTA4Njc=
# 15  jorisvandenbossche    1020496  MDQ6VXNlcjEwMjA0OTY=
# ...
