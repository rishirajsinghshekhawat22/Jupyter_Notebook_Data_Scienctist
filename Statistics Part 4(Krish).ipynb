# %% [markdown]
# # Hypothesis Testing
#
# * Null Hypothesis
# * Alternate Hypothesis
# * Experiment (Significance value)
# * Decision rule
# * Conclustion

# %% [markdown]
# # P value Or Significance Value Or Probability Or Alpa
#
# Keyboard Space Bar Example:
#
# P = 0.1
# It means out of 100 touches 10 time we are touching at a specefic value.
#
# **Confidence Interval**
# * p value or Alpha = 0.05
# * Confidence interval = 1-alpha(0.05) = 0.95 or 95%
#
# * Who will decide Alpha value ?
# * Domain Experts
#
# When we perform Statistical Experiment will give us P-value.
#
# P-value has two different avatars. The one which we will get from the **domain expert** and the other one which we will find after **performing experiments**.
#
# The value we get post performing experiments, we shall then check if it's falling under alpha region or not.
#
# **If P value falls under confidence interval, we accept null hypothesis else we accept alternate hypothesis**
#
# We accept the null hypothesis when it falls under confidence level because it stays close to Mean.
#
# What is the difference between significance value and P value.
#
# * P value is drived by doing statistical experiments.
# * Significance value/Alpha value is given by domain expert.
#
# **There are two ways to judge to accept or reject the null hypothesis**
#
# 1. With Alpha, confidence interval and P value.
# 2. With Alpha, confidence interval, lower and upper bound value and P value. (I explained it in notebook with the help of Gausson distribution)
#
# **For the second step where we find lower and the upper bound we use:**
# * Z-Table
# * T-Table
# * F-Table
#
# Note: When we do stats with programmig we consider p-value option.
# When we do stats theoritically, we consider lower and upper bound.

# %% [markdown]
# # Different Types of Statistical Tests:
# 1. Z Test (Comparison Of Mean) Here we will have Population SD.
# 2. T Test (Comparison Of Mean) Here we will not have Population SD.
# 3. F Test (Comparison Of Variance)
# 4. Anova Test (Analysis Of Variance)
# 5. Chi Square (Comparison between 2 catergorical variables)

# %% [markdown]
# Confidence Interval = 1-Alpha
# * Point Estimate: It is a value of any statistic that estimates the value of a parameter is called point Estimate.
#
# Example: We have a sample mean and then we estimate Population mean.
#
# **If populaton SD is given, we shall use Z test.**
#
# Confidence Interval = Point Estimate +- Margin of error.
# x bar +- Zalpha/2 sigma/Root of n
#
# Sigma = Population SD

# %% [markdown]
# **Problem Statement**
#
# On the verbal section of CAT exam, the standard deviation is 100(Population SD), Sample of 25 test takers is taken . They have a mean of 520. Construct a 95% Confidence interval about the mean.
#
# Solved in notebook. 15th June.
#
#
# 2. On the verbal section of CAT exam, a sample of 25 test takers has a mean of 520 with SD of 80. Construct 95% Confidence Interval about the Mean.
#
# **If population SD is not given than we shall use T-TEST**
#
# Margin Error Formula would be
#
# x bar +- Talpha/2(S/√n )
# S = Sample SD
#
# When population SD is not given, in addition to use the above formula, we shall find **Degree Of Freedom** as well.
#
# **Degree of Freedom = n-1** = 25-1. We will find it in T table. It's like, how many number of choices we have.
#
# # In Z table the first row is of SD, hence we use that when we have SD. In T table we don't have that, hence we use degree of freedom.
#
# **In Z test n should be >= to 30**
#
# **Tailed test is also called Type 1 Error**

# %% [markdown]
# **One Sample Z Test**
#
# **Conditions to do Z test**
# n>= 30
# Population SD should be given.
#
#
# Question: The average IQ = 100 and the SD = 15. A company test a new medication to check whether it increases or decreases the IQ. After taking medicine the sample of 30 participants the IQ was checked and the mean IQ was 140.  Significance value = 0.05.
# Did medication affect intelligence?
#
# * Mean = 100
# * Population SD = 15
# * n = 30
# * New_Mean = 140
# * Alpha = 0.05
# * Two tailed test = Because it may increase of decrease.
#
# * H0/Null Hypothesis = Mean = 100
# * H1/Alternate Hypothesis =  Mean not equal to 100
#
# We calculate Z test statistics.
#
# Z Test Stastics = x_bar-mean/Sigma/root of n.
# =14.60
#
# Conclusion = Our range is between -1.96 to 1.96.
# Z = 14.60, we will gonna reject the null hypothesis as Z doesn't lie under the range, hence it means, it changed the IQ.
#
# **New problem statement**
#
# The data from the above question.
#
# Alpha = 0.30
# What would be confidence interval?
#
# In the Z test, we should seach for the value in the list.
# CI = 1-0.30 = 0.70
#
# To find out Z we need 1-0.15 = 0.85
#
# New Questions :
#
#
# Question: The average IQ = 110 and the SD = 15. A company test a new medication to check whether it increases or decreases the IQ. After taking medicine the sample of 35 participants the IQ was checked and the mean IQ was 120.  Significance value = 0.02.
# Did medication affect intelligence?

# %% [markdown]
# # T test Problem Statements
#
# **One sample T Test**
#
# Conditions
# Population SD is not given.
# Need not to have n>= 30
#
#
# Questions:
# In the population the average IQ is 100, A team of scientists want to test a new medication to see if it has a positive or negative effect on intellegence or no effect at all. A sample of 25 participants have taken the medication and has a mean IQ of 140 with SD as 20. Significance value is 0.05 .Did the medication affect intellegence?
#
# * Population Mean = 100
# * n = 25
# * Sample Mean = 140
# * Sample SD = 20
# * Alpha = .05
# * Degree of freedom = n-1 = 24
#
# * H0 = Mean = 100
# * H1 = Mean not equal to 100
# **T test = xbar-population mean/S/rootofn**

# %% [markdown]
# # Z Score VS Z Test
#
# * **Z Score**            Population Data
# * **Z Test**             Sample Data

# %% [markdown]
# # One Sample Z Test For Propotion.
#
# A survey claims that 9 out of 10 doctors reccommend Aspiron for the patients with headache. To test this claim, a random sample of 100 doctors is obtaine. Out of these 100 doctors, 82 indicate that they recommend Aspiron.
# Is this claim accurate? with Alpha 0.05
#
# 1. Null Hypothesis = P = 0.9 9/10
# 2. Alternate Hypothesis = P != 0.9
#
# Calculation of Z statistcs for propotion.
#
# P_Head = 0.82
# P0 = 0.90
# n=100
#
# **Formula for Z test for propotion**
# Z= P_head-P0/Root of (P0(1-P0)/n)
#
# Z = -2.667
# Reject Null Hypothesis

# %% [markdown]
# 2nd Question
# A survey claims that 7 out of 10 doctors reccommend Aspiron for the patients with headache. To test this claim, a random sample of 100 doctors is obtaine. Out of these 100 doctors, 82 indicate that they recommend Aspiron.
# Is this claim accurate? with Alpha 0.05
#
# 1. Null Hypothesis = P = 0.7 7/10
# 2. Alternate Hypothesis = P != 0.7
